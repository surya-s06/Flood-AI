# %%
import os
import sys

PROJECT_ROOT = os.path.abspath("..")

if PROJECT_ROOT not in sys.path:
    sys.path.insert(0, PROJECT_ROOT)

# %%
from models.vision.dataset import FloodDataset

# %%
import os
import sys

sys.path.append("../models/vision")

# %%
from dataset import FloodDataset

# %%
dataset = FloodDataset(
    "../data/satellite/images",
    "../data/satellite/masks"
)

print(len(dataset))
# Out:
# 290

# %%
import sys

sys.path.append("../models/vision")

from dataset import FloodDataset

# %%
dataset = FloodDataset(
    "../data/satellite/images",
    "../data/satellite/masks"
)

print(len(dataset))
# Out:
# 290

# %%
import inspect
from dataset import FloodDataset

print(inspect.getsource(FloodDataset))
# Out:
# class FloodDataset(Dataset):
#
#     def __init__(self, image_dir, mask_dir):
#
#         self.image_dir = image_dir
#         self.mask_dir = mask_dir
#
#         self.images = sorted(os.listdir(image_dir))
#         self.masks = sorted(os.listdir(mask_dir))
#
#
#     def __len__(self):
#
#         return len(self.images)
#
#
#     def __getitem__(self, index):
#
#         image_name = self.images[index]
#         mask_name = self.masks[index]
#
#         image_path = os.path.join(
#             self.image_dir,
#             image_name
#         )
#
#         mask_path = os.path.join(
#             self.mask_dir,
#             mask_name
#         )
#
#         image = Image.open(image_path)
#         mask = Image.open(mask_path)
#
#         return image, mask

# %%
print(type(dataset))
# Out:
# <class 'dataset.FloodDataset'>

# %%
print(dataset.__class__)
# Out:
# <class 'dataset.FloodDataset'>

# %%
print(dataset.__getitem__)
# Out:
# <bound method Dataset.__getitem__ of <dataset.FloodDataset object at 0x000001F8255BC550>>

# %%
print(type(dataset))
print(dataset.__class__)
print(dataset.__class__.__module__)
print(dataset.__class__.__dict__.keys())
# Out:
# <class 'dataset.FloodDataset'>
# <class 'dataset.FloodDataset'>
# dataset
# dict_keys(['__module__', '__firstlineno__', '__init__', '__len__', '__static_attributes__', '__doc__', '__parameters__'])

# %%
new_dataset = FloodDataset(
    "../data/satellite/images",
    "../data/satellite/masks"
)

print(type(new_dataset))
print(new_dataset.__class__.__dict__.keys())
# Out:
# <class 'dataset.FloodDataset'>
# dict_keys(['__module__', '__firstlineno__', '__init__', '__len__', '__static_attributes__', '__doc__', '__parameters__'])
